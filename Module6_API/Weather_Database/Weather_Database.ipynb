# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# import the requests library.
import requests
from config import weather_key

# %%
# 5. Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# %%
# MAKE SURE TO CHANGE SIZE TO 2000 AFTER TESTING!!!

# 3. Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# 4. Get the nearest city using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 1 | carballo
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | saint-pierre
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | terra santa
# Processing Record 19 of Set 1 | wanaka
# Processing Record 20 of Set 1 | kharp
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | biak
# Processing Record 24 of Set 1 | dunedin
# Processing Record 25 of Set 1 | lagoa
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | edea
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | mendoza
# Processing Record 30 of Set 1 | norman wells
# Processing Record 31 of Set 1 | amalapuram
# Processing Record 32 of Set 1 | oyama
# Processing Record 33 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | tezu
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | muroto
# Processing Record 40 of Set 1 | shelburne
# Processing Record 41 of Set 1 | toftir
# City not found. Skipping...
# Processing Record 42 of Set 1 | sao benedito do rio preto
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | honiara
# Processing Record 46 of Set 1 | coahuayana
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | marv dasht
# City not found. Skipping...
# Processing Record 49 of Set 1 | avera
# Processing Record 50 of Set 1 | darnetal
# Processing Record 1 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 2 | san patricio
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | bilma
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | clovis
# Processing Record 10 of Set 2 | buraydah
# Processing Record 11 of Set 2 | mount gambier
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | camacha
# Processing Record 15 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 2 | rivadavia
# Processing Record 17 of Set 2 | uribia
# Processing Record 18 of Set 2 | okhotsk
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | cidreira
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | bayir
# Processing Record 24 of Set 2 | apiai
# Processing Record 25 of Set 2 | superior
# Processing Record 26 of Set 2 | sitka
# Processing Record 27 of Set 2 | luancheng
# Processing Record 28 of Set 2 | griffith
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | antagan
# City not found. Skipping...
# Processing Record 33 of Set 2 | manresa
# Processing Record 34 of Set 2 | tevaitoa
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 40 of Set 2 | nakamura
# Processing Record 41 of Set 2 | wukari
# Processing Record 42 of Set 2 | mitu
# Processing Record 43 of Set 2 | bathsheba
# Processing Record 44 of Set 2 | esmeralda
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | constantine
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | mattru
# Processing Record 49 of Set 2 | aransas pass
# Processing Record 50 of Set 2 | talnakh
# Processing Record 1 of Set 3 | hamilton
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 3 | ancud
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | hervey bay
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | metaxades
# Processing Record 10 of Set 3 | berlevag
# Processing Record 11 of Set 3 | boden
# Processing Record 12 of Set 3 | sagara
# Processing Record 13 of Set 3 | anakapalle
# Processing Record 14 of Set 3 | marzuq
# Processing Record 15 of Set 3 | muli
# Processing Record 16 of Set 3 | den helder
# Processing Record 17 of Set 3 | chumikan
# Processing Record 18 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 19 of Set 3 | denpasar
# Processing Record 20 of Set 3 | evensk
# Processing Record 21 of Set 3 | mendi
# Processing Record 22 of Set 3 | neepawa
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | barabai
# Processing Record 26 of Set 3 | eureka
# Processing Record 27 of Set 3 | taoudenni
# Processing Record 28 of Set 3 | grand-santi
# Processing Record 29 of Set 3 | impfondo
# Processing Record 30 of Set 3 | college
# Processing Record 31 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 3 | abu dhabi
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | qui nhon
# Processing Record 36 of Set 3 | upernavik
# Processing Record 37 of Set 3 | los palacios
# Processing Record 38 of Set 3 | sheboygan
# Processing Record 39 of Set 3 | smithers
# Processing Record 40 of Set 3 | magadan
# Processing Record 41 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 3 | verkhnevilyuysk
# Processing Record 43 of Set 3 | meulaboh
# Processing Record 44 of Set 3 | aswan
# Processing Record 45 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 3 | new norfolk
# Processing Record 47 of Set 3 | manono
# Processing Record 48 of Set 3 | la ronge
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 50 of Set 3 | maldonado
# Processing Record 1 of Set 4 | opuwo
# Processing Record 2 of Set 4 | cabo san lucas
# Processing Record 3 of Set 4 | nuuk
# Processing Record 4 of Set 4 | narsaq
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | kismayo
# Processing Record 7 of Set 4 | freeport
# Processing Record 8 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 4 | lai
# Processing Record 10 of Set 4 | grindavik
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | hermanus
# Processing Record 13 of Set 4 | shafranovo
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | raduzhnyy
# Processing Record 16 of Set 4 | havelock
# Processing Record 17 of Set 4 | sarka ghat
# Processing Record 18 of Set 4 | marabba
# Processing Record 19 of Set 4 | pevek
# Processing Record 20 of Set 4 | villa sandino
# Processing Record 21 of Set 4 | dakar
# Processing Record 22 of Set 4 | shingu
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | muros
# Processing Record 25 of Set 4 | mandera
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | comodoro rivadavia
# Processing Record 28 of Set 4 | zhangjiakou
# Processing Record 29 of Set 4 | korla
# Processing Record 30 of Set 4 | walvis bay
# Processing Record 31 of Set 4 | svencionys
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | cabedelo
# Processing Record 34 of Set 4 | piacabucu
# Processing Record 35 of Set 4 | badajoz
# Processing Record 36 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 4 | tailai
# Processing Record 38 of Set 4 | keshabpur
# Processing Record 39 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | kanniyakumari
# Processing Record 42 of Set 4 | deputatskiy
# Processing Record 43 of Set 4 | taburao
# City not found. Skipping...
# Processing Record 44 of Set 4 | przhevalskoye
# Processing Record 45 of Set 4 | tuktoyaktuk
# Processing Record 46 of Set 4 | tateyama
# Processing Record 47 of Set 4 | linares
# Processing Record 48 of Set 4 | aykhal
# Processing Record 49 of Set 4 | shahr-e babak
# Processing Record 50 of Set 4 | esperance
# Processing Record 1 of Set 5 | dhidhdhoo
# Processing Record 2 of Set 5 | ulaangom
# Processing Record 3 of Set 5 | rovaniemi
# Processing Record 4 of Set 5 | cherskiy
# Processing Record 5 of Set 5 | brae
# Processing Record 6 of Set 5 | mareeba
# Processing Record 7 of Set 5 | vardo
# Processing Record 8 of Set 5 | bluff
# Processing Record 9 of Set 5 | baijiantan
# Processing Record 10 of Set 5 | verkhnyaya maksakovka
# Processing Record 11 of Set 5 | mikkeli
# Processing Record 12 of Set 5 | atar
# Processing Record 13 of Set 5 | khandbari
# Processing Record 14 of Set 5 | nouadhibou
# Processing Record 15 of Set 5 | jiuquan
# Processing Record 16 of Set 5 | san antonio
# Processing Record 17 of Set 5 | broome
# Processing Record 18 of Set 5 | yerbogachen
# Processing Record 19 of Set 5 | canavieiras
# Processing Record 20 of Set 5 | laiagam
# City not found. Skipping...
# Processing Record 21 of Set 5 | leamington
# Processing Record 22 of Set 5 | alyangula
# Processing Record 23 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 24 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 5 | pangnirtung
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | kirakira
# Processing Record 28 of Set 5 | niquero
# Processing Record 29 of Set 5 | zhangye
# Processing Record 30 of Set 5 | thinadhoo
# Processing Record 31 of Set 5 | boralday
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | lebork
# Processing Record 34 of Set 5 | salalah
# Processing Record 35 of Set 5 | sao filipe
# Processing Record 36 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 5 | severo-kurilsk
# Processing Record 38 of Set 5 | itoman
# Processing Record 39 of Set 5 | dibulla
# Processing Record 40 of Set 5 | novikovo
# Processing Record 41 of Set 5 | vila velha
# Processing Record 42 of Set 5 | manzanillo
# Processing Record 43 of Set 5 | yeppoon
# Processing Record 44 of Set 5 | sorkjosen
# Processing Record 45 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 46 of Set 5 | sao joao da barra
# Processing Record 47 of Set 5 | antofagasta
# Processing Record 48 of Set 5 | andijon
# Processing Record 49 of Set 5 | umm ruwabah
# City not found. Skipping...
# Processing Record 50 of Set 5 | calvillo
# Processing Record 1 of Set 6 | prince rupert
# Processing Record 2 of Set 6 | katherine
# Processing Record 3 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 4 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 6 | gizo
# Processing Record 6 of Set 6 | jinka
# Processing Record 7 of Set 6 | newala
# Processing Record 8 of Set 6 | rosita
# Processing Record 9 of Set 6 | mayo
# Processing Record 10 of Set 6 | pacific grove
# Processing Record 11 of Set 6 | pauri
# Processing Record 12 of Set 6 | luderitz
# Processing Record 13 of Set 6 | lang son
# Processing Record 14 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 15 of Set 6 | harstad
# Processing Record 16 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | panama city
# Processing Record 19 of Set 6 | riyadh
# Processing Record 20 of Set 6 | giddalur
# Processing Record 21 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 6 | vanavara
# Processing Record 23 of Set 6 | tilichiki
# Processing Record 24 of Set 6 | emerald
# Processing Record 25 of Set 6 | seymchan
# Processing Record 26 of Set 6 | maniitsoq
# Processing Record 27 of Set 6 | padang
# Processing Record 28 of Set 6 | kuzedeyevo
# Processing Record 29 of Set 6 | gornopravdinsk
# Processing Record 30 of Set 6 | bengkulu
# Processing Record 31 of Set 6 | half moon bay
# Processing Record 32 of Set 6 | waingapu
# Processing Record 33 of Set 6 | alta floresta
# Processing Record 34 of Set 6 | wanlaweyn
# Processing Record 35 of Set 6 | el faiyum
# City not found. Skipping...
# Processing Record 36 of Set 6 | marau
# Processing Record 37 of Set 6 | la paz
# Processing Record 38 of Set 6 | balabac
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 6 | gravelbourg
# Processing Record 42 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 44 of Set 6 | sabalgarh
# Processing Record 45 of Set 6 | ouallam
# Processing Record 46 of Set 6 | watertown
# Processing Record 47 of Set 6 | srandakan
# Processing Record 48 of Set 6 | lorengau
# Processing Record 49 of Set 6 | mallow
# Processing Record 50 of Set 6 | maine-soroa
# Processing Record 1 of Set 7 | yining
# Processing Record 2 of Set 7 | krasni okny
# Processing Record 3 of Set 7 | flinders
# Processing Record 4 of Set 7 | balikpapan
# Processing Record 5 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 6 of Set 7 | beni
# Processing Record 7 of Set 7 | benguela
# Processing Record 8 of Set 7 | mahibadhoo
# Processing Record 9 of Set 7 | tanout
# Processing Record 10 of Set 7 | sukhothai
# Processing Record 11 of Set 7 | mbandaka
# Processing Record 12 of Set 7 | saint-philippe
# Processing Record 13 of Set 7 | kandrian
# Processing Record 14 of Set 7 | iwanai
# Processing Record 15 of Set 7 | bambous virieux
# Processing Record 16 of Set 7 | suchindram
# Processing Record 17 of Set 7 | nantucket
# Processing Record 18 of Set 7 | tomatlan
# Processing Record 19 of Set 7 | airai
# Processing Record 20 of Set 7 | isangel
# Processing Record 21 of Set 7 | prabumulih
# Processing Record 22 of Set 7 | marsh harbour
# Processing Record 23 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 7 | perelyub
# Processing Record 25 of Set 7 | ilulissat
# Processing Record 26 of Set 7 | lulindi
# Processing Record 27 of Set 7 | lufilufi
# Processing Record 28 of Set 7 | plettenberg bay
# Processing Record 29 of Set 7 | ziro
# Processing Record 30 of Set 7 | tazovskiy
# Processing Record 31 of Set 7 | burnie
# Processing Record 32 of Set 7 | vila
# Processing Record 33 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 34 of Set 7 | cayenne
# Processing Record 35 of Set 7 | labuan
# Processing Record 36 of Set 7 | ocampo
# Processing Record 37 of Set 7 | margate
# Processing Record 38 of Set 7 | senmonorom
# City not found. Skipping...
# Processing Record 39 of Set 7 | tiksi
# Processing Record 40 of Set 7 | sulayman
# Processing Record 41 of Set 7 | orlik
# Processing Record 42 of Set 7 | casambalangan
# Processing Record 43 of Set 7 | minot
# Processing Record 44 of Set 7 | lubaczow
# Processing Record 45 of Set 7 | jibuti
# Processing Record 46 of Set 7 | llanes
# Processing Record 47 of Set 7 | akhmim
# Processing Record 48 of Set 7 | llangefni
# Processing Record 49 of Set 7 | luanda
# Processing Record 50 of Set 7 | magdagachi
# Processing Record 1 of Set 8 | kawalu
# Processing Record 2 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 8 | lexington
# Processing Record 4 of Set 8 | faya
# Processing Record 5 of Set 8 | christiana
# Processing Record 6 of Set 8 | paamiut
# Processing Record 7 of Set 8 | naze
# Processing Record 8 of Set 8 | porto novo
# Processing Record 9 of Set 8 | pimentel
# Processing Record 10 of Set 8 | sorland
# Processing Record 11 of Set 8 | awbari
# Processing Record 12 of Set 8 | richards bay
# Processing Record 13 of Set 8 | medina del campo
# Processing Record 14 of Set 8 | xai-xai
# Processing Record 15 of Set 8 | sibu
# Processing Record 16 of Set 8 | olafsvik
# Processing Record 17 of Set 8 | kang
# Processing Record 18 of Set 8 | palmer
# Processing Record 19 of Set 8 | yulara
# Processing Record 20 of Set 8 | puerto colombia
# Processing Record 21 of Set 8 | saint-joseph
# Processing Record 22 of Set 8 | aneby
# Processing Record 23 of Set 8 | lata
# Processing Record 24 of Set 8 | gilgil
# City not found. Skipping...
# Processing Record 25 of Set 8 | batavia
# Processing Record 26 of Set 8 | tobermory
# Processing Record 27 of Set 8 | kenai
# Processing Record 28 of Set 8 | san roque
# Processing Record 29 of Set 8 | ladario
# Processing Record 30 of Set 8 | burgersdorp
# Processing Record 31 of Set 8 | sabha
# Processing Record 32 of Set 8 | lakes entrance
# Processing Record 33 of Set 8 | pangkalanbuun
# Processing Record 34 of Set 8 | port macquarie
# Processing Record 35 of Set 8 | vila franca do campo
# Processing Record 36 of Set 8 | grand gaube
# Processing Record 37 of Set 8 | teguldet
# Processing Record 38 of Set 8 | sinnamary
# Processing Record 39 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 8 | ixtapa
# Processing Record 41 of Set 8 | sisimiut
# Processing Record 42 of Set 8 | kutum
# Processing Record 43 of Set 8 | campbell river
# Processing Record 44 of Set 8 | codrington
# Processing Record 45 of Set 8 | mgachi
# Processing Record 46 of Set 8 | zhigansk
# Processing Record 47 of Set 8 | georgiyevka
# Processing Record 48 of Set 8 | bayji
# Processing Record 49 of Set 8 | atbasar
# Processing Record 50 of Set 8 | vuktyl
# Processing Record 1 of Set 9 | katsuura
# Processing Record 2 of Set 9 | kruisfontein
# Processing Record 3 of Set 9 | rutana
# Processing Record 4 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 9 | san luis
# Processing Record 6 of Set 9 | skara
# Processing Record 7 of Set 9 | katobu
# Processing Record 8 of Set 9 | aleksandrov gay
# Processing Record 9 of Set 9 | tabou
# Processing Record 10 of Set 9 | kangasala
# Processing Record 11 of Set 9 | banjar
# Processing Record 12 of Set 9 | chapais
# Processing Record 13 of Set 9 | port moresby
# Processing Record 14 of Set 9 | ostersund
# Processing Record 15 of Set 9 | gualmatan
# Processing Record 16 of Set 9 | kez
# Processing Record 17 of Set 9 | cradock
# Processing Record 18 of Set 9 | namibe
# Processing Record 19 of Set 9 | staryy nadym
# Processing Record 20 of Set 9 | marsa matruh
# Processing Record 21 of Set 9 | sjoholt
# Processing Record 22 of Set 9 | sabla
# Processing Record 23 of Set 9 | slave lake
# Processing Record 24 of Set 9 | batagay
# Processing Record 25 of Set 9 | borovoy
# Processing Record 26 of Set 9 | looc
# Processing Record 27 of Set 9 | oriximina
# Processing Record 28 of Set 9 | razole
# Processing Record 29 of Set 9 | fortuna
# Processing Record 30 of Set 9 | huarmey
# Processing Record 31 of Set 9 | kisangani
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | nanortalik
# Processing Record 34 of Set 9 | labuhan
# Processing Record 35 of Set 9 | plasencia
# Processing Record 36 of Set 9 | qaqortoq
# Processing Record 37 of Set 9 | vao
# Processing Record 38 of Set 9 | vysokogornyy
# Processing Record 39 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 9 | palu
# Processing Record 41 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 9 | igrim
# Processing Record 43 of Set 9 | emba
# Processing Record 44 of Set 9 | los llanos de aridane
# Processing Record 45 of Set 9 | mansfield
# Processing Record 46 of Set 9 | mandalgovi
# Processing Record 47 of Set 9 | shinjo
# Processing Record 48 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 9 | rosamorada
# Processing Record 50 of Set 9 | belaya gora
# Processing Record 1 of Set 10 | pisco
# Processing Record 2 of Set 10 | fairbanks
# Processing Record 3 of Set 10 | caucaia
# Processing Record 4 of Set 10 | the valley
# Processing Record 5 of Set 10 | turbat
# Processing Record 6 of Set 10 | north platte
# Processing Record 7 of Set 10 | talavera de la reina
# Processing Record 8 of Set 10 | gumia
# Processing Record 9 of Set 10 | monteagudo
# Processing Record 10 of Set 10 | bantry
# Processing Record 11 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 10 | inongo
# Processing Record 13 of Set 10 | ullapool
# Processing Record 14 of Set 10 | eirunepe
# Processing Record 15 of Set 10 | luwuk
# Processing Record 16 of Set 10 | hvide sande
# Processing Record 17 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 10 | hay river
# Processing Record 19 of Set 10 | altea
# Processing Record 20 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 10 | whakatane
# Processing Record 22 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 10 | clyde river
# Processing Record 24 of Set 10 | willowmore
# Processing Record 25 of Set 10 | boyolangu
# Processing Record 26 of Set 10 | glazov
# Processing Record 27 of Set 10 | bayshore gardens
# Processing Record 28 of Set 10 | seinajoki
# Processing Record 29 of Set 10 | ambilobe
# Processing Record 30 of Set 10 | karasjok
# Processing Record 31 of Set 10 | mahanje
# Processing Record 32 of Set 10 | orange walk
# Processing Record 33 of Set 10 | fallon
# Processing Record 34 of Set 10 | springfield
# Processing Record 35 of Set 10 | rocha
# Processing Record 36 of Set 10 | cape coast
# Processing Record 37 of Set 10 | sorrento
# Processing Record 38 of Set 10 | esmeraldas
# Processing Record 39 of Set 10 | hambantota
# Processing Record 40 of Set 10 | sydney
# Processing Record 41 of Set 10 | caravelas
# Processing Record 42 of Set 10 | haines junction
# Processing Record 43 of Set 10 | guines
# Processing Record 44 of Set 10 | ghorawal
# Processing Record 45 of Set 10 | nacala
# Processing Record 46 of Set 10 | abu kamal
# Processing Record 47 of Set 10 | batemans bay
# Processing Record 48 of Set 10 | boatlaname
# City not found. Skipping...
# Processing Record 49 of Set 10 | anadyr
# Processing Record 50 of Set 10 | seoul
# Processing Record 1 of Set 11 | ugoofaaru
# Processing Record 2 of Set 11 | sabang
# Processing Record 3 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 11 | jurm
# Processing Record 5 of Set 11 | port-gentil
# Processing Record 6 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 11 | sulangan
# Processing Record 8 of Set 11 | methoni
# Processing Record 9 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 11 | beringovskiy
# Processing Record 11 of Set 11 | santa maria
# Processing Record 12 of Set 11 | lucea
# Processing Record 13 of Set 11 | ilhabela
# Processing Record 14 of Set 11 | antipovka
# Processing Record 15 of Set 11 | inuvik
# Processing Record 16 of Set 11 | coihaique
# Processing Record 17 of Set 11 | vestmannaeyjar
# Processing Record 18 of Set 11 | trelew
# Processing Record 19 of Set 11 | san cristobal
# Processing Record 20 of Set 11 | veraval
# Processing Record 21 of Set 11 | katete
# Processing Record 22 of Set 11 | tiarei
# Processing Record 23 of Set 11 | vostok
# Processing Record 24 of Set 11 | bousse
# Processing Record 25 of Set 11 | naifaru
# Processing Record 26 of Set 11 | quatre cocos
# Processing Record 27 of Set 11 | sainte-marie
# Processing Record 28 of Set 11 | amapa
# Processing Record 29 of Set 11 | akdepe
# Processing Record 30 of Set 11 | beterou
# Processing Record 31 of Set 11 | ucluelet
# Processing Record 32 of Set 11 | teya
# Processing Record 33 of Set 11 | hazorasp
# Processing Record 34 of Set 11 | guarapari
# Processing Record 35 of Set 11 | necochea
# Processing Record 36 of Set 11 | olinda
# Processing Record 37 of Set 11 | beyneu
# Processing Record 38 of Set 11 | kulhudhuffushi
# Processing Record 39 of Set 11 | mnogovershinnyy
# Processing Record 40 of Set 11 | moron
# Processing Record 41 of Set 11 | andili
# Processing Record 42 of Set 11 | umm kaddadah
# Processing Record 43 of Set 11 | helong
# Processing Record 44 of Set 11 | middletown
# Processing Record 45 of Set 11 | lindi
# Processing Record 46 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 11 | chicama
# Processing Record 48 of Set 11 | moroni
# Processing Record 49 of Set 11 | nishihara
# Processing Record 50 of Set 11 | katakwi
# Processing Record 1 of Set 12 | xingcheng
# Processing Record 2 of Set 12 | ngunguru
# Processing Record 3 of Set 12 | namatanai
# Processing Record 4 of Set 12 | aldan
# Processing Record 5 of Set 12 | iralaya
# Processing Record 6 of Set 12 | natal
# Processing Record 7 of Set 12 | taksimo
# Processing Record 8 of Set 12 | mananara
# Processing Record 9 of Set 12 | puerto cabezas
# Processing Record 10 of Set 12 | mujiayingzi
# Processing Record 11 of Set 12 | laguna
# Processing Record 12 of Set 12 | kurayoshi
# Processing Record 13 of Set 12 | karatau
# Processing Record 14 of Set 12 | asau
# Processing Record 15 of Set 12 | corinth
# Processing Record 16 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 12 | timra
# Processing Record 18 of Set 12 | fort nelson
# Processing Record 19 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 12 | katangli
# Processing Record 21 of Set 12 | alamos
# Processing Record 22 of Set 12 | maputo
# Processing Record 23 of Set 12 | takob
# City not found. Skipping...
# Processing Record 24 of Set 12 | ambulu
# Processing Record 25 of Set 12 | hammerfest
# Processing Record 26 of Set 12 | saryozek
# Processing Record 27 of Set 12 | hofn
# Processing Record 28 of Set 12 | port blair
# Processing Record 29 of Set 12 | kamaishi
# Processing Record 30 of Set 12 | bereda
# Processing Record 31 of Set 12 | cap-aux-meules
# Processing Record 32 of Set 12 | yaan
# Processing Record 33 of Set 12 | jacareacanga
# Processing Record 34 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 12 | newport
# Processing Record 36 of Set 12 | dera ghazi khan
# Processing Record 37 of Set 12 | dyakonovo
# City not found. Skipping...
# Processing Record 38 of Set 12 | beloha
# Processing Record 39 of Set 12 | harper
# Processing Record 40 of Set 12 | zhezkazgan
# Processing Record 41 of Set 12 | kiruna
# Processing Record 42 of Set 12 | faanui
# Processing Record 43 of Set 12 | puerto escondido
# Processing Record 44 of Set 12 | havre-saint-pierre
# Processing Record 45 of Set 12 | centralia
# Processing Record 46 of Set 12 | la labor
# Processing Record 47 of Set 12 | catalina
# Processing Record 48 of Set 12 | itanhem
# Processing Record 49 of Set 12 | bereslavka
# Processing Record 50 of Set 12 | bahir dar
# Processing Record 1 of Set 13 | tripoli
# Processing Record 2 of Set 13 | ostrovnoy
# Processing Record 3 of Set 13 | lompoc
# Processing Record 4 of Set 13 | camana
# Processing Record 5 of Set 13 | sibay
# Processing Record 6 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 13 | nemuro
# Processing Record 8 of Set 13 | tura
# Processing Record 9 of Set 13 | cuauhtemoc
# Processing Record 10 of Set 13 | morehead
# Processing Record 11 of Set 13 | kaeo
# Processing Record 12 of Set 13 | nieuw amsterdam
# Processing Record 13 of Set 13 | ichinohe
# Processing Record 14 of Set 13 | baruun-urt
# Processing Record 15 of Set 13 | burdur
# Processing Record 16 of Set 13 | alibag
# Processing Record 17 of Set 13 | makakilo city
# Processing Record 18 of Set 13 | dingle
# Processing Record 19 of Set 13 | soyo
# Processing Record 20 of Set 13 | parabel
# Processing Record 21 of Set 13 | guangyuan
# Processing Record 22 of Set 13 | pansoy
# Processing Record 23 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 13 | srednekolymsk
# Processing Record 25 of Set 13 | lasa
# Processing Record 26 of Set 13 | xiaoweizhai
# Processing Record 27 of Set 13 | maraba
# Processing Record 28 of Set 13 | linxia
# Processing Record 29 of Set 13 | waddan
# Processing Record 30 of Set 13 | lavrentiya
# Processing Record 31 of Set 13 | la asuncion
# Processing Record 32 of Set 13 | aleksinac
# Processing Record 33 of Set 13 | kyabe
# Processing Record 34 of Set 13 | birnin kebbi
# Processing Record 35 of Set 13 | sola
# Processing Record 36 of Set 13 | ambon
# Processing Record 37 of Set 13 | antalaha
# Processing Record 38 of Set 13 | pangai
# Processing Record 39 of Set 13 | albox
# Processing Record 40 of Set 13 | lake cowichan
# Processing Record 41 of Set 13 | westport
# Processing Record 42 of Set 13 | baghdad
# Processing Record 43 of Set 13 | luganville
# Processing Record 44 of Set 13 | poya
# Processing Record 45 of Set 13 | mastic beach
# Processing Record 46 of Set 13 | chifeng
# Processing Record 47 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 13 | bermeo
# Processing Record 49 of Set 13 | karpathos
# Processing Record 50 of Set 13 | novopokrovka
# Processing Record 1 of Set 14 | broken hill
# Processing Record 2 of Set 14 | kununurra
# Processing Record 3 of Set 14 | hirara
# Processing Record 4 of Set 14 | papara
# Processing Record 5 of Set 14 | kapit
# Processing Record 6 of Set 14 | ayan
# Processing Record 7 of Set 14 | teknaf
# Processing Record 8 of Set 14 | nyurba
# Processing Record 9 of Set 14 | buta
# Processing Record 10 of Set 14 | high level
# Processing Record 11 of Set 14 | kavaratti
# Processing Record 12 of Set 14 | batagay-alyta
# Processing Record 13 of Set 14 | skibbereen
# Processing Record 14 of Set 14 | udachnyy
# Processing Record 15 of Set 14 | shubarshi
# Processing Record 16 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 17 of Set 14 | monrovia
# Processing Record 18 of Set 14 | fort saint james
# Processing Record 19 of Set 14 | briancon
# Processing Record 20 of Set 14 | grants
# Processing Record 21 of Set 14 | nyrob
# Processing Record 22 of Set 14 | safaga
# Processing Record 23 of Set 14 | bubaque
# Processing Record 24 of Set 14 | sangueya
# Processing Record 25 of Set 14 | belmonte
# Processing Record 26 of Set 14 | vung tau
# Processing Record 27 of Set 14 | coquimbo
# Processing Record 28 of Set 14 | acajutla
# Processing Record 29 of Set 14 | aklavik
# Processing Record 30 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 31 of Set 14 | kaniama
# Processing Record 32 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 14 | san clemente
# Processing Record 34 of Set 14 | adrar
# Processing Record 35 of Set 14 | fenoarivo
# Processing Record 36 of Set 14 | sobolevo
# Processing Record 37 of Set 14 | goma
# Processing Record 38 of Set 14 | fort-shevchenko
# Processing Record 39 of Set 14 | meadow lake
# Processing Record 40 of Set 14 | rognan
# Processing Record 41 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 14 | okhtyrka
# Processing Record 43 of Set 14 | ourossogui
# Processing Record 44 of Set 14 | coyaima
# Processing Record 45 of Set 14 | komsomolskiy
# Processing Record 46 of Set 14 | guiyang
# Processing Record 47 of Set 14 | boende
# Processing Record 48 of Set 14 | buala
# Processing Record 49 of Set 14 | turukhansk
# Processing Record 50 of Set 14 | aromashevo
# Processing Record 1 of Set 15 | sarny
# Processing Record 2 of Set 15 | bardiyah
# Processing Record 3 of Set 15 | sterling
# Processing Record 4 of Set 15 | bardsir
# Processing Record 5 of Set 15 | selma
# Processing Record 6 of Set 15 | ulaanbaatar
# Processing Record 7 of Set 15 | campos altos
# Processing Record 8 of Set 15 | te anau
# Processing Record 9 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 15 | nichinan
# Processing Record 11 of Set 15 | yonibana
# Processing Record 12 of Set 15 | san andres
# Processing Record 13 of Set 15 | upington
# Processing Record 14 of Set 15 | iskateley
# Processing Record 15 of Set 15 | ibra
# Processing Record 16 of Set 15 | dwarka
# Processing Record 17 of Set 15 | ocos
# Processing Record 18 of Set 15 | quesnel
# Processing Record 19 of Set 15 | gore
# Processing Record 20 of Set 15 | darhan
# Processing Record 21 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 15 | el campo
# Processing Record 24 of Set 15 | nelson bay
# Processing Record 25 of Set 15 | springdale
# Processing Record 26 of Set 15 | goderich
# Processing Record 27 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 15 | lugo
# Processing Record 29 of Set 15 | derzhavinsk
# Processing Record 30 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 31 of Set 15 | honningsvag
# Processing Record 32 of Set 15 | sechura
# Processing Record 33 of Set 15 | atasu
# Processing Record 34 of Set 15 | totness
# Processing Record 35 of Set 15 | yumen
# Processing Record 36 of Set 15 | aginskoye
# Processing Record 37 of Set 15 | talaya
# Processing Record 38 of Set 15 | maragogi
# Processing Record 39 of Set 15 | stawell
# Processing Record 40 of Set 15 | poum
# Processing Record 41 of Set 15 | intipuca
# Processing Record 42 of Set 15 | san quintin
# Processing Record 43 of Set 15 | basoko
# Processing Record 44 of Set 15 | brahmapuri
# City not found. Skipping...
# Processing Record 45 of Set 15 | sakakah
# Processing Record 46 of Set 15 | khor
# Processing Record 47 of Set 15 | tashara
# Processing Record 48 of Set 15 | port keats
# Processing Record 49 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 15 | baiao
# Processing Record 1 of Set 16 | haapiti
# Processing Record 2 of Set 16 | ikorodu
# Processing Record 3 of Set 16 | sistranda
# Processing Record 4 of Set 16 | linqiong
# Processing Record 5 of Set 16 | svetlogorsk
# Processing Record 6 of Set 16 | innisfail
# Processing Record 7 of Set 16 | mercedes
# Processing Record 8 of Set 16 | victor harbor
# Processing Record 9 of Set 16 | wamba
# Processing Record 10 of Set 16 | ust-kuyga
# Processing Record 11 of Set 16 | university place
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.7393  -90.3518     75.16        79          93
# 1        Barrow      US  71.2906 -156.7887    -11.18        77          90
# 2       Iqaluit      CA  63.7506  -68.5145     16.25        75          97
# 3     Saskylakh      RU  71.9167  114.0833    -44.19       100          66
# 4     Carnarvon      AU -24.8667  113.6333     68.07        83          40
# 5       Ushuaia      AR -54.8000  -68.3000     51.46        58          75
# 6      Carballo      ES  43.2130   -8.6910     49.51        86          55
# 7   Provideniya      RU  64.3833 -173.3000      8.28        92         100
# 8   Yellowknife      CA  62.4560 -114.3525      0.41        97         100
# 9          Hilo      US  19.7297 -155.0900     83.28        75          20
#
#    Wind Speed Current Description
# 0        9.95     overcast clouds
# 1        5.75     overcast clouds
# 2        7.47     overcast clouds
# 3        3.49       broken clouds
# 4       20.71    scattered clouds
# 5       17.27       broken clouds
# 6        6.71       broken clouds
# 7        8.63     overcast clouds
# 8        7.78     overcast clouds
# 9        5.75          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

#Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
